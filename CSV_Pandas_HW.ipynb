# %% [markdown]
# 1)

# %%
import pandas as pd
acc_df = pd.read_csv('acc_players-2324F.csv', sep=',', header = 1, encoding='latin1')
acc_df.head()
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %% [markdown]
# 2)

# %%
acc_df['PTS'].sum()
# Out:
# 38411

# %%
acc_df[['Player', 'MP']].sort_values(by='MP', ascending=False).head(1)
# Out:
#             Player    MP
# 135  Casey Morsell  1333

# %%
acc_df[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
# Out:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %% [markdown]
# 3)

# %%
filtered_acc_df = acc_df.query('MP >500')
filtered_acc_df.head()
# Out:
#    Rk         Player Class Pos          School   G    MP  TRB  AST  STL  ...  \
# 2   3  Prince Aligbe    SO   F  Boston College  35   651  119   21   15  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33   746  137   29   32  ...
# 5   6  Armando Bacot    SR   F  North Carolina  37  1123  380   56   22  ...
# 7   8  Reece Beekman    SR   G        Virginia  34  1114  124  212   68  ...
# 9  10     Chris Bell    SO   F        Syracuse  32   865   75   21   18  ...
#
#    TOV   PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 2   30   51  164  0.435  0.522  0.147  0.620   9.4  0.9  -1.3
# 4   13   35  216  0.417  0.563  0.295  0.737  18.0  2.9   7.9
# 5   60  100  538  0.540  0.544  0.400  0.781  24.6  6.1   8.9
# 7   70   43  486  0.443  0.487  0.310  0.754  23.4  4.9  10.5
# 9   26   58  384  0.434  0.459  0.420  0.842  14.9  2.2   3.3
#
# [5 rows x 21 columns]

# %%
filtered_acc_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(1)
# Out:
#           Player  AST
# 7  Reece Beekman  212

# %%
filtered_acc_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
# Out:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150

# %%
filtered_acc_df[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
# Out:
#             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %% [markdown]
# 4)

# %%
acc_df.groupby('School')['PTS'].sum().reset_index()
# Out:
#             School   PTS
# 0   Boston College  2667
# 1          Clemson  2785
# 2             Duke  2830
# 3    Florida State  2526
# 4     Georgia Tech  2272
# 5       Louisville  2304
# 6       Miami (FL)  2424
# 7         NC State  3101
# 8   North Carolina  3032
# 9       Notre Dame  2113
# 10      Pittsburgh  2495
# 11        Syracuse  2442
# 12        Virginia  2140
# 13   Virginia Tech  2547
# 14     Wake Forest  2733

# %%
acc_df.groupby('School')['AST'].sum().reset_index()
# Out:
#             School  AST
# 0   Boston College  509
# 1          Clemson  533
# 2             Duke  551
# 3    Florida State  406
# 4     Georgia Tech  425
# 5       Louisville  356
# 6       Miami (FL)  454
# 7         NC State  536
# 8   North Carolina  536
# 9       Notre Dame  335
# 10      Pittsburgh  452
# 11        Syracuse  442
# 12        Virginia  509
# 13   Virginia Tech  514
# 14     Wake Forest  429

# %%
total_pts_school_df = acc_df.groupby('School')['PTS'].sum().reset_index()
total_pts_school_df.sort_values(by='PTS', ascending=False).head(3)
# Out:
#            School   PTS
# 7        NC State  3101
# 8  North Carolina  3032
# 2            Duke  2830

# %% [markdown]
# Extra Credit

# %%
top_5_players_pts = acc_df[['Player', 'PTS']].sort_values(by='PTS', ascending=False).head(5)
top_5_players_pts.head()
# Out:
#             Player  PTS
# 42        RJ Davis  784
# 81        DJ Horne  677
# 70         PJ Hall  659
# 175  Hunter Sallis  613
# 80    Blake Hinson  609

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.barplot(x='Player', y='PTS', data=top_5_players_pts)
plt.title('Points for Top 5 Point Scorers')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="FG%", y="WS", data=acc_df)
plt.title('Player Win Shares by Field Goal Percentage')
plt.show()

# %%
r = acc_df['FG%'].corr(acc_df['WS'])
print(r)
# Out:
# 0.4210663894199787

# %% [markdown]
# ## Reflection

# %% [markdown]
#   From this assignment, I was able to learn how to successfully read a CSV file in Python, and then load that data into a Pandas dataframe, and I also learned how to make sure that the headers get included in the dataframe when it gets loaded in. I also gained knowledge on how to select certain columns from the dataset and perform operations on those particular columns (ex. calculate the total number of assists by all the players in the dataset). I also learned how to use queries with a Pandas dataframe in order to do things like select all the rows with a certain number of points, assists, etc. Another skill that this assignment helped me develop was grouping by a particular column such as team and performing operations on those groupings, such as summing over points within those groupings, finding the mean of particular values in those groupings, etc. Finally, I appreciated being able to develop my skills in creating plots from dataframes, such as the bar plot which I had limited experience with, and the scatter plot, which I had no experience with in terms of using Python/Pandas dataframes to create these plots. I look forward to being able to utilize these skills in further projects because this assignment demonstrated a way to easily read in a CSV file, put it into a Pandas dataframe, which provides you with easy ways to view the data in the dataframes (by using the head function or the display function), and easy ways to perform analyses on the data such as finding totals, means, grouping by particular categories, etc. This alone will be helpful for future projects because any time you are working with data, it is important to be able to get a good understanding of the data by viewing it and by performing analyses to find trends or interesting findings. Finally, the data visualization aspect of the assignment will definitely be useful in the future because I have learned simple ways to show particular aspects of the dataframe in clear and visually pleasing ways which is always important if you want to present your findings to other people.

# %% [markdown]
# The most challenging aspect of the assignment was mastering the syntax involved with the different ways we can manipulate data using Pandas dataframes. I am not too familiar with Pandas, so I was not used to all the different syntax that is used to do things like access particular columns of the dataframes, group by particular columns, etc. The way that I overcame these challenges was by looking back at our in-class guides, such as Pandas_tutorial.ipynb, taking particular lines of code (ex. filtered_df = dataframe.query('one <= 2')), and identifying what each part of the code was doing. I felt that this helped me get a way better grasp of the code because instead of just trying to memorize a lot of syntax, I was understanding why things were being done in particular places. This way, if something was going wrong with my code, I could understand why my code was wrong rather than having to use trial and error to correct my mistakes.

# %% [markdown]
# I think what I learned from this assignment in terms of analyzing the ACC dataset could be broadly applied to a lot of different datasets. Something that I was thinking about was the upcoming election season. If there were to be a dataset or datasets that contained information about voting/votes from different states, similar techniques could be used to do things such as filter out only states that have over a certain voter turnout percentage, find the total amount of votes for the whole country, find which states had the greatest voter turnout percentage, etc., all of which would provide a lot of important information about voting that could demonstrate particular trends in voting that shaped the election, etc. The heart of data science is definitely being able to find trends or interesting findings in data, and this assignment provided me with strategies on how to filter, sort, group, and display data in very intuitive ways which are skills that I will undoubtedly use in my future endeavors.
